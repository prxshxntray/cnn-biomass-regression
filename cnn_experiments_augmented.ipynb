# %%
import numpy as np
import torch

from cnn_workflow_utils import (
    TARGET_COLUMNS,
    create_kfold,
    mixup,
    scale_targets,
)

df_wide, scaler = scale_targets(df_wide, target_cols=TARGET_COLUMNS)

# %% [markdown]
# Cross-Validation Split

# %%
kf = create_kfold(n_splits=5, shuffle=True, random_state=42)

# %% [markdown]
# Mixup

# %%
# Mixup is imported from cnn_workflow_utils and can be applied inside the training loop.
# Example: images, targets = mixup(images, targets, alpha=0.4)
